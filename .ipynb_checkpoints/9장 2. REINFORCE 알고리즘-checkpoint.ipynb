# %% [markdown]
# # 9장 정책기반 에이전트
# REINFORCE 알고리즘의 그라디언트 수식 :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Q1. G_t가 왜 편향되지 않았지? Q는 G_t의 기댓값이라 편향되지 않은 값.. 평균으로 가지만 G_t 값 하나하나는 편향된거 아닌가요?

# %% [markdown]
# ## 9.2 REINFORCE 알고리즘

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# repeat
#
#     pi\_θ(s,a)로 에피소드 하나에 해당하는 데이터 얻고,
#
#     해당 데이터로 θ를 업데이트 하고,
#
#     업데이트된 pi\_θ(s,a)를 이용해 다음 에피소드의 경험을 얻고
#
#     해당 데이터로 θ를 업데이트 하고,
#
# until
#
#     θ가 변하지 않거나 / 성능 개선이 일어나지 않을 때 까지

# %% [markdown]
# ## 2. REINFORCE 구현
#
# 데이터가 주어졌을 때, 데이터를 이용해 계산해야 하는 gradient 식:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 파이토치나 텐서플로우에서 미분된 수식 사용 x - > 미분 전 식으로 구해야함
#
# ▽\_θJ(θ)대신 미분하기 전 값을 optimizer에게 넘겨주어야함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# optimizer는 손실함수를 minimize하는 방향으로 업데이트함 => 우리는 maximize
#
# 그렇기 때문에 -를 취해줌

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98 # 무조건 끝나는 episode라면 gamma == 1도 가능하다.

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        # weight를 정의  
        self.fc1 = nn.Linear(4, 128) # fully connected first layer
        self.fc2 = nn.Linear(128, 2) # fully connected second layer
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    # 얜 언제 불러지는걸까요?
    def forward(self, x):
        x = F.relu(self.fc1(x)) # first layer 통과 후 비선형 함수 통과 
        x = F.softmax(self.fc2(x), dim=0) # second layer 통과 후 sofrmax로 합이 1이 되는 확률로 만들어
        return x
      
    # s, a pair 저장
    def put_data(self, item): 
        self.data.append(item)
        
    # 2-(C) presudo code
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]: # return을 재귀적으로 뒤에서부터 더하면서 계산
            R = r + gamma * R # Return Gt
            loss = -torch.log(prob) * R # loss function
            loss.backward() # gradient 계산
        self.optimizer.step() # Adam optimizer update 진해
        self.data = []
# Out:
# /home/ogangza/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Q1. forward 함수는 언제 불러지는 걸까요?
#
# - 모델 구조
#
# 길이 4인 벡터가 인풋으로 들어가, 2개의 액션에 대한 확률값을 리턴하는 네트워크입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - train_net에서 아래 수식이 실제 사용됩니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - G_t
#
# R이 G_t에 해당하며, 거꾸로 계산하고 있으므로 순간마다 R에는 해당 틱부터~게임끝까지 받은 보상값이 저장되어있습니다.
#
# - loss
#
# 모든 데이터에 대해 loss를 계산하여 backward 함수를 호출하면 loss에 대한 그라디언트가 계산되어 계속 더해집니다.
#
# 해당 루프가 끝나면 optimizer.step이 실행되면 축적된 그라디언트를 이용해 뉴럴넷의 파라미터가 업데이트 됩니다.

# %%
# main role: 경험을 쌓는 역할 
def main():
    env = gym.make('CartPole-v1')
    # presudo code 1번
    pi = Policy()
    score = 0.0
    print_interval = 20
    
    
    for n_epi in range(10000):
        # 2-(A) presudo code
        s = env.reset() # env 초기화 상태를 받은 numpy 배열 n
        done = False
        
        # 2-(B) presudo code
        # presudo code 2번
        while not done: # CartPole-v1 forced to terminates at 500 step.
                        # Cartpole이 500번 성공하면 보통 성공이라고 봄
            prob = pi(torch.from_numpy(s).float()) # Pi에 (numpy 배열을 pytorch로 바꾼) state를 넣으면
            #각 action들의 확률이 리턴 Tensor(0.0255, -0.0159, -0.04898, -0.0408) 
            # 실제로 뽑으니 2.. 왜 길이가 4일까? 
            # 흥선님의 발표로 알았다..! (카트위치, 카트속도, 막대 각도, 막대 각속도)
#             print(prob) (0.4588, 0.543`~)
            
            m = Categorical(prob) # prob 중 높은 확률 값을 리턴 
#             print(m)
            
            a = m.sample() 
            # 이러한 확률을 가진 action에서 직접 sampling하면 cartpole의 경우에는 
            #action이 0 아니면 1 두가지중 하나로 나옴 Tensor(0)
#             print(a)
            
            s_prime, r, done, info = env.step(a.item()) 
            # 그 action을 env.step에 넣어주면 다음 상태, 보상, 겜 종료 여부를 받는다. 
            
            pi.put_data((r,prob[a])) 
            # policy 객체에 학습에 써야하기 때문에 reward, 내가 선택한 action인 prob[a] 확률을 모은다. 
            # 내가 선택하지 않은 action의 확률인 prob 쓰이지 않는다. 
            
            s = s_prime # next state 
            score += r 
        
        # 2-(C) presudo code
        pi.train_net()
        
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()

# %% [markdown]
# Q1. prob의 길이는 왜 4일까요? 액션은 두가지중 하나라했는데^\_^,,
#
# - Categorical(prob)
#
# 액션 선택 방법이 범주형 정책일 경우
#
# 다른 방식으론 Normal이 있습니다. 이 경우 rsample()의 메소드를 사용한다고 하는데 어느 경우에 저 메소드를 사용하는진 이해 못했슴다^\_^,,
#
# <br>
#
# - 액션을 선택하는 방법
#
# pi가 계산한 액션별 확률에다 m.sample()을 통해 하나의 액션을 샘플링 하는 방식
#
# 이때 pi확률이 높다 -> 액션을 더 자주
#
# pi 확률이 낮다 -> 액션을 덜 뽑는다
#
# 위 과정으로 sampling된 액션 실행하면 => 전이된 상태, 보상, done등의 정보를 env로 부터 받습니다. (즉, 실제로 에이전트가 동작해본다는 것)

# %%
if __name__ == '__main__':
    main()
# Out:
# # of episode :20, avg score : 23.35
# # of episode :40, avg score : 22.3
# # of episode :60, avg score : 21.8
# # of episode :80, avg score : 18.75
# # of episode :100, avg score : 27.6
# # of episode :120, avg score : 32.4
# # of episode :140, avg score : 25.85
# # of episode :160, avg score : 26.65
# # of episode :180, avg score : 21.4
# # of episode :200, avg score : 33.3
# # of episode :220, avg score : 30.75
# # of episode :240, avg score : 26.35
# # of episode :260, avg score : 34.2
# # of episode :280, avg score : 26.4
# # of episode :300, avg score : 37.3
# # of episode :320, avg score : 29.3
# # of episode :340, avg score : 36.8
# # of episode :360, avg score : 38.05
# # of episode :380, avg score : 40.7
# # of episode :400, avg score : 30.5
# # of episode :420, avg score : 43.55
# # of episode :440, avg score : 36.4
# # of episode :460, avg score : 41.65
# # of episode :480, avg score : 50.05
# # of episode :500, avg score : 42.65
# # of episode :520, avg score : 44.2
# # of episode :540, avg score : 43.1
# # of episode :560, avg score : 57.45
# # of episode :580, avg score : 63.75
# # of episode :600, avg score : 48.35
# # of episode :620, avg score : 51.05
# # of episode :640, avg score : 44.75
# # of episode :660, avg score : 47.65
# # of episode :680, avg score : 52.4
# # of episode :700, avg score : 47.95
# # of episode :720, avg score : 51.15
# # of episode :740, avg score : 59.3
# # of episode :760, avg score : 73.55
# # of episode :780, avg score : 75.6
# # of episode :800, avg score : 61.7
# # of episode :820, avg score : 69.6
# # of episode :840, avg score : 58.25
# # of episode :860, avg score : 76.2
# # of episode :880, avg score : 57.75
# # of episode :900, avg score : 73.65
# # of episode :920, avg score : 76.4
# # of episode :940, avg score : 72.0
# # of episode :960, avg score : 74.0
# # of episode :980, avg score : 92.4
# # of episode :1000, avg score : 98.45
# # of episode :1020, avg score : 98.45
# # of episode :1040, avg score : 104.2
# # of episode :1060, avg score : 120.5
# # of episode :1080, avg score : 95.15
# # of episode :1100, avg score : 110.7
# # of episode :1120, avg score : 136.15
# # of episode :1140, avg score : 141.5
# # of episode :1160, avg score : 141.0
# # of episode :1180, avg score : 138.1
# # of episode :1200, avg score : 110.5
# # of episode :1220, avg score : 132.6
# # of episode :1240, avg score : 147.6
# # of episode :1260, avg score : 194.95
# # of episode :1280, avg score : 142.0
# # of episode :1300, avg score : 181.8
# # of episode :1320, avg score : 181.45
# # of episode :1340, avg score : 146.35
# # of episode :1360, avg score : 193.9
# # of episode :1380, avg score : 185.95
# # of episode :1400, avg score : 173.5
# # of episode :1420, avg score : 166.35
# # of episode :1440, avg score : 167.4
# # of episode :1460, avg score : 157.85
# # of episode :1480, avg score : 195.1
# # of episode :1500, avg score : 202.6
# # of episode :1520, avg score : 212.55
# # of episode :1540, avg score : 190.75
# # of episode :1560, avg score : 211.55
# # of episode :1580, avg score : 252.9
# # of episode :1600, avg score : 228.95
# # of episode :1620, avg score : 235.25
# # of episode :1640, avg score : 262.5
# # of episode :1660, avg score : 228.35
# # of episode :1680, avg score : 197.45
# # of episode :1700, avg score : 264.3
# # of episode :1720, avg score : 189.3
# # of episode :1740, avg score : 201.65
# # of episode :1760, avg score : 210.05
# # of episode :1780, avg score : 256.1
# # of episode :1800, avg score : 247.3
# # of episode :1820, avg score : 201.4
# # of episode :1840, avg score : 250.25
# # of episode :1860, avg score : 189.55
# # of episode :1880, avg score : 270.4
# # of episode :1900, avg score : 285.1
# # of episode :1920, avg score : 274.0
# # of episode :1940, avg score : 261.75
# # of episode :1960, avg score : 223.65
# # of episode :1980, avg score : 250.05
# # of episode :2000, avg score : 184.7
# # of episode :2020, avg score : 305.95
# # of episode :2040, avg score : 248.45
# # of episode :2060, avg score : 322.7
# # of episode :2080, avg score : 246.9
# # of episode :2100, avg score : 263.75
# # of episode :2120, avg score : 274.1
# # of episode :2140, avg score : 259.2
# # of episode :2160, avg score : 251.95
# # of episode :2180, avg score : 242.3
# # of episode :2200, avg score : 281.6
# # of episode :2220, avg score : 313.75
# # of episode :2240, avg score : 257.75
# # of episode :2260, avg score : 208.85
# # of episode :2280, avg score : 257.05
# # of episode :2300, avg score : 302.55
# # of episode :2320, avg score : 284.3
# # of episode :2340, avg score : 330.45
# # of episode :2360, avg score : 315.35
# # of episode :2380, avg score : 317.2
# # of episode :2400, avg score : 307.05
# # of episode :2420, avg score : 300.65
# # of episode :2440, avg score : 255.5
# # of episode :2460, avg score : 285.25
# # of episode :2480, avg score : 328.9
# # of episode :2500, avg score : 345.75
# # of episode :2520, avg score : 319.15
# # of episode :2540, avg score : 327.55
# # of episode :2560, avg score : 331.4
# # of episode :2580, avg score : 295.85
# # of episode :2600, avg score : 306.4
# # of episode :2620, avg score : 295.7
# # of episode :2640, avg score : 266.6
# # of episode :2660, avg score : 245.0
# # of episode :2680, avg score : 309.1
# # of episode :2700, avg score : 348.65
# # of episode :2720, avg score : 338.35
# # of episode :2740, avg score : 387.6
# # of episode :2760, avg score : 330.45
# # of episode :2780, avg score : 287.2
# # of episode :2800, avg score : 287.95
# # of episode :2820, avg score : 314.75
# # of episode :2840, avg score : 367.7
# # of episode :2860, avg score : 323.9
# # of episode :2880, avg score : 390.35
# # of episode :2900, avg score : 363.5
# # of episode :2920, avg score : 388.65
# # of episode :2940, avg score : 383.2
# # of episode :2960, avg score : 292.45
# # of episode :2980, avg score : 348.75
# # of episode :3000, avg score : 352.35
# # of episode :3020, avg score : 375.75
# # of episode :3040, avg score : 349.6
# # of episode :3060, avg score : 320.8
# # of episode :3080, avg score : 306.55
# # of episode :3100, avg score : 309.05
# # of episode :3120, avg score : 295.7
# # of episode :3140, avg score : 292.25
# # of episode :3160, avg score : 284.55
# # of episode :3180, avg score : 287.35
# # of episode :3200, avg score : 262.2
# # of episode :3220, avg score : 308.7
# # of episode :3240, avg score : 274.7
# # of episode :3260, avg score : 286.0
# # of episode :3280, avg score : 342.4
# # of episode :3300, avg score : 339.9
# # of episode :3320, avg score : 397.2
# # of episode :3340, avg score : 356.1
# # of episode :3360, avg score : 332.05
# # of episode :3380, avg score : 410.55
# # of episode :3400, avg score : 368.55
# # of episode :3420, avg score : 373.5
# # of episode :3440, avg score : 336.55
# # of episode :3460, avg score : 344.5
# # of episode :3480, avg score : 303.3
# # of episode :3500, avg score : 333.45
# # of episode :3520, avg score : 318.3
# # of episode :3540, avg score : 383.8
# # of episode :3560, avg score : 380.35
# # of episode :3580, avg score : 386.95
# # of episode :3600, avg score : 358.45
# # of episode :3620, avg score : 394.4
# # of episode :3640, avg score : 392.0
# # of episode :3660, avg score : 373.45
# # of episode :3680, avg score : 398.5
# # of episode :3700, avg score : 358.0
# # of episode :3720, avg score : 413.5
# # of episode :3740, avg score : 327.25
# # of episode :3760, avg score : 388.85
# # of episode :3780, avg score : 364.05
# # of episode :3800, avg score : 356.65
# # of episode :3820, avg score : 345.3
# # of episode :3840, avg score : 405.55
# # of episode :3860, avg score : 350.2
# # of episode :3880, avg score : 346.65
# # of episode :3900, avg score : 354.4
# # of episode :3920, avg score : 373.25
# # of episode :3940, avg score : 336.85
# # of episode :3960, avg score : 340.6
# # of episode :3980, avg score : 285.45
# # of episode :4000, avg score : 313.25
# # of episode :4020, avg score : 379.8
# # of episode :4040, avg score : 312.35
# # of episode :4060, avg score : 323.85
# # of episode :4080, avg score : 375.15
# # of episode :4100, avg score : 349.05
# # of episode :4120, avg score : 340.55
# # of episode :4140, avg score : 402.75
# # of episode :4160, avg score : 378.1
# # of episode :4180, avg score : 425.75
# # of episode :4200, avg score : 393.3
# # of episode :4220, avg score : 350.1
# # of episode :4240, avg score : 372.0
# # of episode :4260, avg score : 348.9
# # of episode :4280, avg score : 348.35
# # of episode :4300, avg score : 410.1
# # of episode :4320, avg score : 348.35
# # of episode :4340, avg score : 394.5
# # of episode :4360, avg score : 364.3
# # of episode :4380, avg score : 338.55
# # of episode :4400, avg score : 316.0
# # of episode :4420, avg score : 309.2
# # of episode :4440, avg score : 389.95
# # of episode :4460, avg score : 348.7
# # of episode :4480, avg score : 391.05
# # of episode :4500, avg score : 344.6
# # of episode :4520, avg score : 400.45
# # of episode :4540, avg score : 366.2
# # of episode :4560, avg score : 333.15
# # of episode :4580, avg score : 433.65
# # of episode :4600, avg score : 417.1
# # of episode :4620, avg score : 396.2
# # of episode :4640, avg score : 396.0
# # of episode :4660, avg score : 415.8
# # of episode :4680, avg score : 393.2
# # of episode :4700, avg score : 449.8
# # of episode :4720, avg score : 375.2
# # of episode :4740, avg score : 405.8
# # of episode :4760, avg score : 458.8
# # of episode :4780, avg score : 439.7
# # of episode :4800, avg score : 390.65
# # of episode :4820, avg score : 363.4
# # of episode :4840, avg score : 405.9
# # of episode :4860, avg score : 365.8
# # of episode :4880, avg score : 446.9
# # of episode :4900, avg score : 436.9
# # of episode :4920, avg score : 353.4
# # of episode :4940, avg score : 449.4
# # of episode :4960, avg score : 410.95
# # of episode :4980, avg score : 446.35
# # of episode :5000, avg score : 401.7
# # of episode :5020, avg score : 417.6
# # of episode :5040, avg score : 437.5
# # of episode :5060, avg score : 433.4
# # of episode :5080, avg score : 441.2
# # of episode :5100, avg score : 429.5
# # of episode :5120, avg score : 426.7
# # of episode :5140, avg score : 374.9
# # of episode :5160, avg score : 386.4
# # of episode :5180, avg score : 415.05
# # of episode :5200, avg score : 436.5
# # of episode :5220, avg score : 430.4
# # of episode :5240, avg score : 394.5
# # of episode :5260, avg score : 385.7
# # of episode :5280, avg score : 396.95
# # of episode :5300, avg score : 385.05
# # of episode :5320, avg score : 434.9
# # of episode :5340, avg score : 419.5
# # of episode :5360, avg score : 374.7
# # of episode :5380, avg score : 351.55
# # of episode :5400, avg score : 420.05
# # of episode :5420, avg score : 432.7
# # of episode :5440, avg score : 404.85
# # of episode :5460, avg score : 366.85
# # of episode :5480, avg score : 342.55
# # of episode :5500, avg score : 357.95
# # of episode :5520, avg score : 368.6
# # of episode :5540, avg score : 399.9
# # of episode :5560, avg score : 391.55
# # of episode :5580, avg score : 428.6
# # of episode :5600, avg score : 387.85
# # of episode :5620, avg score : 418.3
# # of episode :5640, avg score : 459.3
# # of episode :5660, avg score : 444.55
# # of episode :5680, avg score : 464.05
# # of episode :5700, avg score : 446.5
# # of episode :5720, avg score : 465.85
# # of episode :5740, avg score : 444.15
# # of episode :5760, avg score : 455.85
# # of episode :5780, avg score : 435.1
# # of episode :5800, avg score : 390.9
# # of episode :5820, avg score : 406.6
# # of episode :5840, avg score : 393.25
# # of episode :5860, avg score : 378.45
# # of episode :5880, avg score : 380.6
# # of episode :5900, avg score : 343.75
# # of episode :5920, avg score : 349.6
# # of episode :5940, avg score : 376.1
# # of episode :5960, avg score : 357.15
# # of episode :5980, avg score : 363.25
# # of episode :6000, avg score : 389.0
# # of episode :6020, avg score : 343.85
# # of episode :6040, avg score : 319.1
# # of episode :6060, avg score : 402.35
# # of episode :6080, avg score : 353.8
# # of episode :6100, avg score : 367.7
# # of episode :6120, avg score : 370.0
# # of episode :6140, avg score : 423.15
# # of episode :6160, avg score : 354.95
# # of episode :6180, avg score : 411.75
# # of episode :6200, avg score : 408.2
# # of episode :6220, avg score : 437.0
# # of episode :6240, avg score : 402.55
# # of episode :6260, avg score : 352.9
# # of episode :6280, avg score : 431.0
# # of episode :6300, avg score : 418.45
# # of episode :6320, avg score : 438.85
# # of episode :6340, avg score : 438.5
# # of episode :6360, avg score : 475.15
# # of episode :6380, avg score : 453.9
# # of episode :6400, avg score : 437.9
# # of episode :6420, avg score : 438.65
# # of episode :6440, avg score : 494.3
# # of episode :6460, avg score : 466.65
# # of episode :6480, avg score : 494.9
# # of episode :6500, avg score : 476.0
# # of episode :6520, avg score : 477.45
# # of episode :6540, avg score : 467.2
# # of episode :6560, avg score : 406.25
# # of episode :6580, avg score : 346.45
# # of episode :6600, avg score : 327.55
# # of episode :6620, avg score : 390.45
# # of episode :6640, avg score : 462.75
# # of episode :6660, avg score : 389.65
# # of episode :6680, avg score : 378.45
# # of episode :6700, avg score : 429.5
# # of episode :6720, avg score : 465.55
# # of episode :6740, avg score : 468.0
# # of episode :6760, avg score : 448.9
# # of episode :6780, avg score : 476.75
# # of episode :6800, avg score : 435.9
# # of episode :6820, avg score : 479.85
# # of episode :6840, avg score : 470.25
# # of episode :6860, avg score : 474.0
# # of episode :6880, avg score : 476.75
# # of episode :6900, avg score : 463.45
# # of episode :6920, avg score : 451.85
# # of episode :6940, avg score : 459.35
# # of episode :6960, avg score : 476.8
# # of episode :6980, avg score : 456.05
# # of episode :7000, avg score : 439.55
# # of episode :7020, avg score : 454.9
# # of episode :7040, avg score : 415.95
# # of episode :7060, avg score : 390.05
# # of episode :7080, avg score : 457.8
# # of episode :7100, avg score : 486.2
# # of episode :7120, avg score : 437.05
# # of episode :7140, avg score : 454.45
# # of episode :7160, avg score : 495.9
# # of episode :7180, avg score : 464.35
# # of episode :7200, avg score : 476.95
# # of episode :7220, avg score : 465.75
# # of episode :7240, avg score : 492.3
# # of episode :7260, avg score : 449.0
# # of episode :7280, avg score : 463.5
# # of episode :7300, avg score : 490.85
# # of episode :7320, avg score : 475.4
# # of episode :7340, avg score : 445.0
# # of episode :7360, avg score : 454.35
# # of episode :7380, avg score : 475.1
# # of episode :7400, avg score : 474.6
# # of episode :7420, avg score : 477.45
# # of episode :7440, avg score : 409.7
# # of episode :7460, avg score : 455.9
# # of episode :7480, avg score : 481.3
# # of episode :7500, avg score : 451.25
# # of episode :7520, avg score : 452.15
# # of episode :7540, avg score : 452.7
# # of episode :7560, avg score : 416.1
# # of episode :7580, avg score : 448.6
# # of episode :7600, avg score : 412.2
# # of episode :7620, avg score : 458.35
# # of episode :7640, avg score : 450.5
# # of episode :7660, avg score : 408.7
# # of episode :7680, avg score : 430.35
# # of episode :7700, avg score : 411.9
# # of episode :7720, avg score : 466.55
# # of episode :7740, avg score : 445.65
# # of episode :7760, avg score : 457.05
# # of episode :7780, avg score : 485.4
# # of episode :7800, avg score : 435.35
# # of episode :7820, avg score : 444.65
# # of episode :7840, avg score : 454.1
# # of episode :7860, avg score : 414.95
# # of episode :7880, avg score : 473.05
# # of episode :7900, avg score : 467.7
# # of episode :7920, avg score : 435.35
# # of episode :7940, avg score : 446.5
# # of episode :7960, avg score : 438.95
# # of episode :7980, avg score : 425.9
# # of episode :8000, avg score : 402.25
# # of episode :8020, avg score : 384.95
# # of episode :8040, avg score : 453.85
# # of episode :8060, avg score : 428.6
# # of episode :8080, avg score : 418.8
# # of episode :8100, avg score : 417.4
# # of episode :8120, avg score : 435.55
# # of episode :8140, avg score : 437.3
# # of episode :8160, avg score : 446.2
# # of episode :8180, avg score : 452.2
# # of episode :8200, avg score : 463.2
# # of episode :8220, avg score : 447.45
# # of episode :8240, avg score : 451.8
# # of episode :8260, avg score : 465.15
# # of episode :8280, avg score : 468.5
# # of episode :8300, avg score : 452.15
# # of episode :8320, avg score : 461.9
# # of episode :8340, avg score : 475.5
# # of episode :8360, avg score : 457.75
# # of episode :8380, avg score : 440.75
# # of episode :8400, avg score : 467.7
# # of episode :8420, avg score : 461.15
# # of episode :8440, avg score : 479.35
# # of episode :8460, avg score : 448.0
# # of episode :8480, avg score : 453.9
# # of episode :8500, avg score : 424.6
# # of episode :8520, avg score : 444.1
# # of episode :8540, avg score : 475.6
# # of episode :8560, avg score : 459.0
# # of episode :8580, avg score : 427.65
# # of episode :8600, avg score : 423.35
# # of episode :8620, avg score : 454.4
# # of episode :8640, avg score : 460.1
# # of episode :8660, avg score : 455.05
# # of episode :8680, avg score : 413.9
# # of episode :8700, avg score : 419.8
# # of episode :8720, avg score : 398.05
# # of episode :8740, avg score : 389.15
# # of episode :8760, avg score : 398.65
# # of episode :8780, avg score : 449.6
# # of episode :8800, avg score : 435.5
# # of episode :8820, avg score : 431.9
# # of episode :8840, avg score : 455.9
# # of episode :8860, avg score : 482.1
# # of episode :8880, avg score : 444.25
# # of episode :8900, avg score : 464.8
# # of episode :8920, avg score : 449.75
# # of episode :8940, avg score : 478.5
# # of episode :8960, avg score : 470.6
# # of episode :8980, avg score : 485.9
# # of episode :9000, avg score : 473.25
# # of episode :9020, avg score : 486.25
# # of episode :9040, avg score : 478.15
# # of episode :9060, avg score : 486.5
# # of episode :9080, avg score : 463.25
# # of episode :9100, avg score : 475.05
# # of episode :9120, avg score : 459.75
# # of episode :9140, avg score : 457.95
# # of episode :9160, avg score : 467.85
# # of episode :9180, avg score : 421.0
# # of episode :9200, avg score : 467.15
# # of episode :9220, avg score : 479.45
# # of episode :9240, avg score : 482.4
# # of episode :9260, avg score : 488.45
# # of episode :9280, avg score : 465.8
# # of episode :9300, avg score : 450.5
# # of episode :9320, avg score : 459.2
# # of episode :9340, avg score : 494.2
# # of episode :9360, avg score : 500.0
# # of episode :9380, avg score : 478.25
# # of episode :9400, avg score : 490.85
# # of episode :9420, avg score : 455.55
# # of episode :9440, avg score : 464.5
# # of episode :9460, avg score : 464.4
# # of episode :9480, avg score : 381.95
# # of episode :9500, avg score : 302.15
# # of episode :9520, avg score : 262.4
# # of episode :9540, avg score : 250.05
# # of episode :9560, avg score : 225.9
# # of episode :9580, avg score : 207.4
# # of episode :9600, avg score : 236.95
# # of episode :9620, avg score : 244.65
# # of episode :9640, avg score : 226.25
# # of episode :9660, avg score : 231.45
# # of episode :9680, avg score : 253.95
# # of episode :9700, avg score : 219.25
# # of episode :9720, avg score : 256.85
# # of episode :9740, avg score : 254.25
# # of episode :9760, avg score : 297.2
# # of episode :9780, avg score : 320.3
# # of episode :9800, avg score : 289.05
# # of episode :9820, avg score : 272.05
# # of episode :9840, avg score : 299.8
# # of episode :9860, avg score : 308.5
# # of episode :9880, avg score : 260.15
# # of episode :9900, avg score : 329.35
# # of episode :9920, avg score : 373.0
# # of episode :9940, avg score : 397.35
# # of episode :9960, avg score : 418.15
# # of episode :9980, avg score : 479.4

# %% [markdown]
# # print적용할 때
#
# ![image.png](attachment:image.png)
